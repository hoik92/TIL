# %%
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn

# %% [markdown]
# # 지도 학습 알고리즘

# %% [markdown]
# ## forge 데이터셋

# %%
# 지도 학습 알고리즘(Supervised learning)
# 예제에 사용할 데이터셋 (forge 데이터셋 - 인위적으로 만든 이진 분류 데이터셋)
X, y = mglearn.datasets.make_forge()
# 산점도
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["클래스 0", "클래스 1"], loc=4)
plt.xlabel("첫 번째 특성(First specificity)")
plt.ylabel("두 번째 특성(Second specificity)")
print(f"X.shape: {X.shape}")
# Out:
# X.shape: (26, 2)
# c:\users\student\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# ## wave 데이터셋

# %%
# wave 데이터셋 (회귀 알고리즘)
X, y = mglearn.datasets.make_wave(n_samples=40)
plt.plot(X, y, 'o')
plt.xlabel("특성(Specificity)")
plt.ylabel("타겟(Target)")
# Out:
# Text(0, 0.5, '타겟(Target)')

# %% [markdown]
# ## 유방암 데이터셋

# %%
# 유방암 데이터셋 (이진 분류 알고리즘의 실제 데이터셋)
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
print(f"cancer.keys():\n{cancer.keys()}")
# Out:
# cancer.keys():
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
# 유방암 데이터셋 형태
print(f"유방암 데이터의 형태: {cancer.data.shape}")
# 569개의 데이터와 30개의 특성
# Out:
# 유방암 데이터의 형태: (569, 30)

# %%
# 569개 중 212개는 악성, 357개는 양성
print("클래스별 샘플 개수:\n{}".format({n: v for n, v in zip(cancer.target_names, np.bincount(cancer.target))}))
# Out:
# 클래스별 샘플 개수:
# {'malignant': 212, 'benign': 357}

# %%
# feature_names 는 각 특성의 의미
print(f"특성 이름:\n{cancer.feature_names}")
# Out:
# 특성 이름:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %% [markdown]
# ## 보스턴 주택가격 데이터셋

# %%
# 보스턴 주택가격 데이터셋 (회귀 분석 알고리즘의 실제 데이터셋)
from sklearn.datasets import load_boston
boston = load_boston()
print(f"데이터의 형태: {boston.data.shape}")
# 506개의 데이터와 13개의 특성
# Out:
# 데이터의 형태: (506, 13)

# %%
# 13개의 입력 특성을 특성끼리 곱하여 특성을 확장
X, y = mglearn.datasets.load_extended_boston()
print(f"X.shape: {X.shape}")
# 506개의 데이터와 104개의 특성
# Out:
# X.shape: (506, 104)

# %% [markdown]
# ## k-최근접 이웃 알고리즘

# %%
# k-NN 알고리즘
# k-최근접 이웃 분류
mglearn.plots.plot_knn_classification(n_neighbors=1)
# 별 모양이 추가된 데이터, 이 데이터와 가장 가까운 훈련 데이터를 연결
# Out:
# c:\users\student\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)

# %%
mglearn.plots.plot_knn_classification(n_neighbors=3)
# Out:
# c:\users\student\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# 훈련 세트와 테스트 세트로 분류
from sklearn.model_selection import train_test_split
X, y = mglearn.datasets.make_forge()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
# Out:
# c:\users\student\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# k-NN 알고리즘으로 훈련 세트를 학습
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=3)

clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
# 예측하기
print(f"테스트 세트 예측: {clf.predict(X_test)}")
# Out:
# 테스트 세트 예측: [1 0 1 0 1 0 0]

# %%
# 정확도
print(f"테스트 세트 정확도: {clf.score(X_test, y_test):.2f}")
# Out:
# 테스트 세트 정확도: 0.86

# %% [markdown]
# ## KNeighborsClassifier 분석

# %%
# KNeighborsClassifier 분석
# 결정 경계 (decision boundary)
fig, axes = plt.subplots(1, 3, figsize=(10, 3))

for n_neighbors, ax in zip([1, 3, 9], axes):
    # fit 메소드는 self 객체를 반환
    # 따라서 객체 생성과 fit 메소드를 한 줄에 쓸 수 있음
    clf = KNeighborsClassifier(n_neighbors=n_neighbors).fit(X, y)
    mglearn.plots.plot_2d_separator(clf, X, fill=True, eps=0.5, ax=ax, alpha=.4)
    mglearn.discrete_scatter(X[:, 0], X[:, 1], y, ax=ax)
    ax.set_title(f"{n_neighbors} 이웃")
    ax.set_xlabel("특성(specificity) 0")
    ax.set_ylabel("특성(specificity) 1")
axes[0].legend(loc=3)

# %%
# 모델의 복잡도와 일반화 사이의 관계 (유방암 데이터셋)
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=66)

training_accuracy = []
test_accuracy = []
# 1에서 10까지 n_neighbors를 적용
neighbors_settings = range(1, 11)

for n_neighbors in neighbors_settings:
    # 모델 생성
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(X_train, y_train)
    # 훈련 세트 정확도 저장
    training_accuracy.append(clf.score(X_train, y_train))
    # 일반화 정확도 저장
    test_accuracy.append(clf.score(X_test, y_test))
    
plt.plot(neighbors_settings, training_accuracy, label="훈련 정확도(Training Accuracy)")
plt.plot(neighbors_settings, test_accuracy, label="테스트 정확도(Test Accuracy)")
plt.ylabel("정확도(Accuracy)")
plt.xlabel("n_neighbors")
plt.legend()

# 최근접 이웃 수에 따른 훈련 세트와 세트 정확도 그래프
# 이웃의 수가 너무 적으면 모델이 너무 복잡하여 정확도가 낮아짐
# 이웃의 수가 너무 많으면 모델이 너무 단순하여 정확도가 낮아짐

# %% [markdown]
# ## k-최근접 이웃 회귀

# %%
# wave 데이터셋을 이용한 k-NN 회귀 분석
# 별 모양의 데이터가 테스트 데이터
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %%
# k-최근접 이웃 회귀 알고리즘
from sklearn.neighbors import KNeighborsRegressor

X, y = mglearn.datasets.make_wave(n_samples=40)

# wave 데이터셋을 훈련 세트와 테스트 세트로 분류
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# 이웃의 수를 3으로 하여 모델의 객체 생성 및 훈련 데이터셋을 이용하여 모델 학습
reg = KNeighborsRegressor(n_neighbors=3).fit(X_train, y_train)

# %%
# 예측하기
print(f"테스트 세트 예측:\n{reg.predict(X_test)}")
# Out:
# 테스트 세트 예측:
# [-0.05396539  0.35686046  1.13671923 -1.89415682 -1.13881398 -1.63113382
#   0.35686046  0.91241374 -0.44680446 -1.13881398]

# %%
# 정확도
print(f"테스트 세트 R^2: {reg.score(X_test, y_test):.2f}")
# Out:
# 테스트 세트 R^2: 0.83

# %% [markdown]
# ## KNeighborsRegressor 분석

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
# -3과 3 사이에 1000개의 데이터 포인트 생성
line = np.linspace(-3, 3, 1000).reshape(-1, 1)
for n_neighbors, ax in zip([1, 3, 9], axes):
    # 1, 3, 9 이웃을 사용한 예측
    reg = KNeighborsRegressor(n_neighbors=n_neighbors)
    reg.fit(X_train, y_train)
    ax.plot(line, reg.predict(line))
    ax.plot(X_train, y_train, '^', c=mglearn.cm2(0), markersize=8)
    ax.plot(X_test, y_test, 'v', c=mglearn.cm2(1), markersize=8)
    
    ax.set_title(f"{n_neighbors}neighbor's training score: {reg.score(X_train, y_train):.2f} test score: {reg.score(X_test, y_test):.2f}")
    ax.set_xlabel("특성(Feature)")
    ax.set_ylabel("타겟(Target)")
axes[0].legend(["Prediction", "Training data/target", "Test data/target"], loc="best")

# 이웃이 하나일 경우 훈련 세트의 각 데이터가 예측에 너무 큰 영향을 줌
# 이웃이 많이 사용하면 훈련 데이터에는 잘 안 맞을 수 있지만 더 안정된 예측을 얻게 됨
